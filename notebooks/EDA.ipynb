# %% [markdown]
# ## Load packages

# %%
import pandas as pd

# %% [markdown]
# ## Articles

# %%
articles = pd.read_csv('../data/articles.csv')

# %%
articles.head()
# Out:
#                 by  descendants        id  \
# 0     todsacerdoti          607  24563698
# 1  themodelplumber          126  24562850
# 2              luu           27  24553085
# 3        pseudolus           56  24553369
# 4         jeanyang           24  24561119
#
#                                                 kids  score  \
# 0  24563821 24563987 24565829 24564488 24563843 2...    711
# 1  24563705 24563838 24563276 24563478 24565992 2...    310
# 2  24563230 24562887 24562049 24564895 24562235 2...    227
# 3  24563122 24565813 24562283 24562375 24563752 2...     94
# 4  24561495 24562538 24565366 24564334 24561573 2...     87
#
#                   time                                              title  \
# 0  2020-09-23 08:38:33  Firefox usage is down 85% despite Mozilla's to...
# 1  2020-09-23 06:04:45  How to say no, for the people pleaser who alwa...
# 2  2020-09-22 13:04:22                                         Small Tech
# ...

# %% [markdown]
# ## Comments

# %%
comments = pd.read_csv('../data/comments.csv')

# %%
comments.head()
# Out:
#            by          id                  kids      parent  \
# 0     hateful  22162912.0            [22162939]  22162102.0
# 1  Centigonal  22162461.0  [22162482, 22162498]  22162102.0
# 2   leothekim  22162249.0                    {}  22162102.0
# 3   sbmthakur  22162508.0                    {}  22162102.0
# 4     koliber  22162936.0            [22163451]  22162102.0
#
#                                                 text                 time  \
# 0  It wasn't just me!Though it was interesting th...  2020-01-27 20:36:20
# 1     up for me now. Google SREs must be busy today!  2020-01-27 19:48:02
# 2                             Drive is down as well.  2020-01-27 19:26:25
# 3  Seems like they got it up quickly. But would s...  2020-01-27 19:52:36
# 4  So were portions of Google Slides. I could not...  2020-01-27 20:38:25
#
#       type deleted dead
# 0  comment     NaN  NaN
# 1  comment     NaN  NaN
# 2  comment     NaN  NaN
# 3  comment     NaN  NaN
# 4  comment     NaN  NaN
